# %%
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM


# 1. Data
input_string="hihello"
char_set=sorted(set(input_string))
encoder={k:v for v,k in enumerate(char_set)}
decoder={v:k for v,k in enumerate(char_set)}
print('# Encoder')
print(encoder)
encoded_string= [encoder[c] for c in input_string ]

print('# Encoded string')
print(encoded_string)

string_width=len(input_string)
input_w=4
output_w=string_width-input_w

x=[]
y=[]
for i in range(output_w):
 x.append( encoded_string[i:i+input_w]  )
 y.append( encoded_string[input_w+i]    )

x=array(x)
y=array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
print(x,y)


# 2. Keras Model
model = Sequential()
model.add(LSTM(10, activation = 'relu', input_shape=(input_w,1)))
# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))

model.summary()


# 3. Training
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)

# 4.Test
test_string="hihe"
x_input = array([encoder[c] for c in test_string ] )
x_input = x_input.reshape((1,input_w,1))
print(f"# test string\n {test_string}")
yhat = model.predict(x_input)
out=decoder[round(yhat[0][0])]
print(f"# test output\n {out}")
# Out:
# # Encoder
# {'e': 0, 'h': 1, 'i': 2, 'l': 3, 'o': 4}
# # Encoded string
# [1, 2, 1, 0, 3, 3, 4]
# [[[1]
#   [2]
#   [1]
#   [0]]
#
#  [[2]
#   [1]
#   [0]
#   [3]]
#
#  [[1]
#   [0]
#   [3]
#   [3]]] [3 3 4]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10)                480
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 541
# Trainable params: 541
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 0s 3ms/step - loss: 12.3347
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.7481
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.1886
# Epoch 4/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.5989
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.0508
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.6543
# Epoch 7/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.1153
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.5722
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.1882
# Epoch 10/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.6525
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.2254
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.7918
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.4360
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.9949
# Epoch 15/100
# 3/3 [==============================] - 0s 3ms/step - loss: 5.5625
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.1784
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 4.7263
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 4.3864
# Epoch 19/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.9975
# Epoch 20/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.6597
# Epoch 21/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.2692
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.9273
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5777
# Epoch 24/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.3048
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9968
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6968
# Epoch 27/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4341
# Epoch 28/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2146
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0202
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8217
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6605
# Epoch 32/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5482
# Epoch 33/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4543
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3765
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3606
# Epoch 36/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3152
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2890
# Epoch 38/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2853
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3045
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3008
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2980
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2921
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2863
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2771
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2715
# Epoch 46/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2667
# Epoch 47/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2652
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2600
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2559
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2509
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2471
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2449
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2402
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2360
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2325
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2292
# Epoch 57/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2249
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2225
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2186
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2143
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2117
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2109
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2055
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2010
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1994
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1961
# Epoch 67/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1909
# Epoch 68/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1882
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1847
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1818
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1785
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1773
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1744
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1689
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1656
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1627
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1620
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1572
# Epoch 79/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1536
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1508
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1472
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1442
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1428
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1391
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1363
# Epoch 86/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1335
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1310
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1288
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1258
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1242
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1201
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1174
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1166
# Epoch 94/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1128
# Epoch 95/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1111
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1090
# Epoch 97/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1049
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1031
# Epoch 99/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1012
# Epoch 100/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0992
# # test string
#  hihe
# # test output
#  l
