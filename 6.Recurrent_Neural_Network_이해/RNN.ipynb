# %%
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %% [markdown]
# # 1. Data

# %%
input_string="hihello"
char_set=sorted(set(input_string))
encoder={k:v for v,k in enumerate(char_set)}
decoder={v:k for v,k in enumerate(char_set)}
print('# Encoder')
print(encoder)
encoded_string= [encoder[c] for c in input_string ]

print('# Encoded string')
print(encoded_string)

string_width=len(input_string)
input_w=4
output_w=string_width-input_w

x=[]
y=[]
for i in range(output_w):
 x.append( encoded_string[i:i+input_w]  )
 y.append( encoded_string[input_w+i]    )

x=array(x)
y=array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
print(x,y)
# Out:
# # Encoder
# {'e': 0, 'h': 1, 'i': 2, 'l': 3, 'o': 4}
# # Encoded string
# [1, 2, 1, 0, 3, 3, 4]
# [[[1]
#   [2]
#   [1]
#   [0]]
#
#  [[2]
#   [1]
#   [0]
#   [3]]
#
#  [[1]
#   [0]
#   [3]
#   [3]]] [3 3 4]

# %% [markdown]
# # 2. Keras Model

# %%
model = Sequential()
model.add(LSTM(10, activation = 'relu', input_shape=(input_w,1)))
# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10)                480
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 541
# Trainable params: 541
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Training

# %%
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.1631
# Epoch 2/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.0030
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.8337
# Epoch 4/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.6528
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.4873
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.2908
# Epoch 7/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.1225
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.9279
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.7461
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.5473
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.3132
# Epoch 12/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.1360
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.9127
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.7041
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.4708
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.2081
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 5.9738
# Epoch 18/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.7633
# Epoch 19/100
# 3/3 [==============================] - 0s 3ms/step - loss: 5.5082
# Epoch 20/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.2523
# Epoch 21/100
# 3/3 [==============================] - 0s 3ms/step - loss: 4.9497
# Epoch 22/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.7236
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 4.4093
# Epoch 24/100
# 3/3 [==============================] - 0s 3ms/step - loss: 4.1386
# Epoch 25/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.8922
# Epoch 26/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6052
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.2813
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 3.0305
# Epoch 29/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7397
# Epoch 30/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4517
# Epoch 31/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1583
# Epoch 32/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8685
# Epoch 33/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6342
# Epoch 34/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3650
# Epoch 35/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1574
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9575
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7555
# Epoch 38/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6006
# Epoch 39/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4813
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3427
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2958
# Epoch 42/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2149
# Epoch 43/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1899
# Epoch 44/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2036
# Epoch 45/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1865
# Epoch 46/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1912
# Epoch 47/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2066
# Epoch 48/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2003
# Epoch 49/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1994
# Epoch 50/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1950
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1893
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1914
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1811
# Epoch 54/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1817
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 56/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1778
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1776
# Epoch 58/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1746
# Epoch 59/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1738
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1720
# Epoch 61/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1720
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1720
# Epoch 63/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1679
# Epoch 64/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1665
# Epoch 65/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1667
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1649
# Epoch 67/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1633
# Epoch 68/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1616
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1613
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1597
# Epoch 71/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1604
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1593
# Epoch 73/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1565
# Epoch 74/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1552
# Epoch 75/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1539
# Epoch 76/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1535
# Epoch 77/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1536
# Epoch 78/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1521
# Epoch 79/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1498
# Epoch 80/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1488
# Epoch 81/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1489
# Epoch 82/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1471
# Epoch 83/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1461
# Epoch 84/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1456
# Epoch 85/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1448
# Epoch 86/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1431
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1432
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1419
# Epoch 89/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1415
# Epoch 90/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1422
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1397
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1398
# Epoch 93/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1386
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1380
# Epoch 95/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1393
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1360
# Epoch 97/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1352
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1354
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1343
# Epoch 100/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1327

# %% [markdown]
# # 4.Test

# %%
test_string="hihe"
x_input = array([encoder[c] for c in test_string ] )
x_input = x_input.reshape((1,input_w,1))
print(f"# test string\n {test_string}")
yhat = model.predict(x_input)
out=decoder[round(yhat[0][0])]
print(f"# test output\n {out}")
# Out:
# # test string
#  hihe
# # test output
#  l
