# %%
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU


# 1. Data
input_string="hihello"
char_set=sorted(set(input_string))
encoder={k:v for v,k in enumerate(char_set)}
decoder={v:k for v,k in enumerate(char_set)}
print('# Encoder')
print(encoder)
encoded_string= [encoder[c] for c in input_string ]

print('# Encoded string')
print(encoded_string)

string_width=len(input_string)
input_w=4
output_w=string_width-input_w

x=[]
y=[]
for i in range(output_w):
 x.append( encoded_string[i:i+input_w]  )
 y.append( encoded_string[input_w+i]    )

x=array(x)
y=array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
print(x,y)


# 2. Keras Model
model = Sequential()
# model.add(LSTM(10, activation = 'relu', input_shape=(input_w,1)))
model.add(GRU(10, activation = 'relu', input_shape=(input_w,1)))

# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))

model.summary()


# 3. Training
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)

# 4.Test
test_string="hihe"
x_input = array([encoder[c] for c in test_string ] )
x_input = x_input.reshape((1,input_w,1))
print(f"# test string\n {test_string}")
yhat = model.predict(x_input)
out=decoder[round(yhat[0][0])]
print(f"# test output\n {out}")
# Out:
# # Encoder
# {'e': 0, 'h': 1, 'i': 2, 'l': 3, 'o': 4}
# # Encoded string
# [1, 2, 1, 0, 3, 3, 4]
# [[[1]
#   [2]
#   [1]
#   [0]]
#
#  [[2]
#   [1]
#   [0]
#   [3]]
#
#  [[1]
#   [0]
#   [3]
#   [3]]] [3 3 4]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 10)                390
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 451
# Trainable params: 451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 0s 3ms/step - loss: 11.8047
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.6992
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.5715
# Epoch 4/100
# 3/3 [==============================] - 0s 3ms/step - loss: 11.4750
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.3563
# Epoch 6/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.2346
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 11.1415
# Epoch 8/100
# 3/3 [==============================] - 0s 3ms/step - loss: 11.0233
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.9163
# Epoch 10/100
# 3/3 [==============================] - 0s 3ms/step - loss: 10.8079
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 10.7008
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.5977
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.4790
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 10.3537
# Epoch 15/100
# 3/3 [==============================] - 0s 3ms/step - loss: 10.2304
# Epoch 16/100
# 3/3 [==============================] - 0s 3ms/step - loss: 10.1251
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.9874
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.8618
# Epoch 19/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.7261
# Epoch 20/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.5786
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.4520
# Epoch 22/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.3116
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 9.1552
# Epoch 24/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.9948
# Epoch 25/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.8166
# Epoch 26/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.6591
# Epoch 27/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.4672
# Epoch 28/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.2953
# Epoch 29/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.0632
# Epoch 30/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.8756
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.6492
# Epoch 32/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.4045
# Epoch 33/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.1317
# Epoch 34/100
# 3/3 [==============================] - 0s 3ms/step - loss: 6.8883
# Epoch 35/100
# 3/3 [==============================] - 0s 3ms/step - loss: 6.6137
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.3235
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 6.0334
# Epoch 38/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.6821
# Epoch 39/100
# 3/3 [==============================] - 0s 3ms/step - loss: 5.3216
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 4.9830
# Epoch 41/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.5899
# Epoch 42/100
# 3/3 [==============================] - 0s 3ms/step - loss: 4.2004
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 3.7993
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 3.3835
# Epoch 45/100
# 3/3 [==============================] - 0s 5ms/step - loss: 2.9756
# Epoch 46/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5061
# Epoch 47/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0632
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5743
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1298
# Epoch 50/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7378
# Epoch 51/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4129
# Epoch 52/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2327
# Epoch 53/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1628
# Epoch 54/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1265
# Epoch 55/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1486
# Epoch 56/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1891
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1867
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1622
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1547
# Epoch 60/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1289
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1007
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1014
# Epoch 63/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1140
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1135
# Epoch 65/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1119
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1073
# Epoch 67/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1051
# Epoch 68/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1024
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1004
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0987
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0977
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0971
# Epoch 73/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0968
# Epoch 74/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0977
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0975
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0985
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0973
# Epoch 78/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 79/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0949
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0967
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0932
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0947
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0935
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0922
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0943
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0925
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0899
# Epoch 88/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0906
# Epoch 89/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0902
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0900
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0890
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 93/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0876
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 95/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0862
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0857
# Epoch 97/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0871
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 99/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0855
# Epoch 100/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0845
# # test string
#  hihe
# # test output
#  l
